# %%
L = ['Density', 'Geographical Risk', 'Number of Housing Units','Percentage Latino','Total Population', 'Bachelors Rate', 'Area of Zipcode',]

res =[.2185, .079, .065, .062, .094, .084, .080]
zipped = sorted(zip(L, res), key = lambda x: x[-1], reverse = True)
for i in zipped:
    print(i)
    
dic = {e[0]: e[1] for e in zipped}

plt.bar([x for x in range(len(res))], dic.values())
    
    
import pylab as plt
import seaborn as sns
fig, ax = plt.subplots(1,1, figsize=(8, 5))
ax = sns.barplot(x=list(range(7)), y=[e[1] for e in zipped], )
ax.set(xlabel= 'Features', ylabel='Importance', xticklabels=[e[0] for e in clear], )
ax.legend(loc=6, bbox_to_anchor=(0.55, 0.75), labels=clear)
plt.setp(ax.get_xticklabels(), rotation=20, ha="right", rotation_mode="anchor")
def change_width(ax, new_value) :
    for patch in ax.patches :
        current_width = patch.get_width()
        diff = current_width - new_value

        # we change the bar width
        patch.set_width(new_value)

        # we recenter the bar
        patch.set_x(patch.get_x() + diff * .6)

change_width(ax, .6)
# Out:
# ('Density', 0.2185)
# ('TotalPop', 0.094)
# ('BachelorsRate', 0.084)
# ('ZipArea', 0.08)
# ('Area_weighted_risk', 0.079)
# ('HousingUnits', 0.065)
# ('PercLatino', 0.062)
