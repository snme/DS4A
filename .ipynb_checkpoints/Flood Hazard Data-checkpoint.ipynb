# %%
import base64
import datetime
import json
import os
import numpy as np
import pandas as pd

# %%
local_folder = '.'
# Read the data file and take a look at the data
df = pd.read_csv('./NFHL by Tract.csv')

df.shape
# Out:
# /opt/conda/lib/python3.6/site-packages/IPython/core/interactiveshell.py:3020: DtypeWarning: Columns (18) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# (147520, 30)

# %%
new_df = df.copy()

# new_df = new_df.drop(columns = ["OBJECTID", "DFIRM_ID", "VERSION_ID", "V_DATUM", "GFID", "SHAPE_Length", "SHAPE_Area", "OBJECTID_2", "GEOID", "ALAND", "AWATER", "INTPTLAT", "INTPTLON", "SOURCE_CIT", "DUAL_ZONE", "DEP_REVERT","BFE_REVERT", "VEL_UNIT", "STATIC_BFE", "DEPTH", "STUDY_TYP", "FLD_AR_ID", "AR_REVERT", "AR_SUBTRV", "VELOCITY", "LEN_UNIT" ])

new_df.head()
# Out:
#    OBJECTID DFIRM_ID VERSION_ID   FLD_AR_ID STUDY_TYP FLD_ZONE  \
# 0     31722   22001C    1.1.1.0  22001C_563        NP        X
# 1     31723   22001C    1.1.1.0  22001C_478        NP       AE
# 2     31755   22001C    1.1.1.0  22001C_599        NP       AE
# 3     31767   22001C    1.1.1.0  22001C_559        NP        A
# 4     31786   22001C    1.1.1.0  22001C_649        NP       AE
#
#                      ZONE_SUBTY SFHA_TF  STATIC_BFE V_DATUM    ...      \
# 0  AREA OF MINIMAL FLOOD HAZARD       F     -9999.0     NaN    ...
# 1                           NaN       T     -9999.0     NaN    ...
# 2                           NaN       T     -9999.0     NaN    ...
# 3                           NaN       T     -9999.0     NaN    ...
# 4                      FLOODWAY       T     -9999.0     NaN    ...
#
#            GFID SHAPE_Length    SHAPE_Area OBJECTID_2         GEOID  \
# 0  20110509LOMR     0.002779  1.789667e-07        1.0  2.200196e+10
# 1  20110509LOMR     0.064587  4.082684e-05        1.0  2.200196e+10
# 2  20110509LOMR     0.102957  5.973499e-05        1.0  2.200196e+10
# 3  20110509LOMR     0.154251  3.987519e-04        1.0  2.200196e+10
# 4  20110509LOMR     0.063092  3.696726e-05        1.0  2.200196e+10
#
#             NAMELSAD       ALAND  AWATER   INTPTLAT   INTPTLON
# 0  Census Tract 9601  47243493.0     0.0  30.410129 -92.217192
# 1  Census Tract 9601  47243493.0     0.0  30.410129 -92.217192
# 2  Census Tract 9601  47243493.0     0.0  30.410129 -92.217192
# 3  Census Tract 9601  47243493.0     0.0  30.410129 -92.217192
# 4  Census Tract 9601  47243493.0     0.0  30.410129 -92.217192
#
# [5 rows x 30 columns]

# %%
df.columns
# Out:
# Index(['OBJECTID', 'DFIRM_ID', 'VERSION_ID', 'FLD_AR_ID', 'STUDY_TYP',
#        'FLD_ZONE', 'ZONE_SUBTY', 'SFHA_TF', 'STATIC_BFE', 'V_DATUM', 'DEPTH',
#        'LEN_UNIT', 'VELOCITY', 'VEL_UNIT', 'AR_REVERT', 'AR_SUBTRV',
#        'BFE_REVERT', 'DEP_REVERT', 'DUAL_ZONE', 'SOURCE_CIT', 'GFID',
#        'SHAPE_Length', 'SHAPE_Area', 'OBJECTID_2', 'GEOID', 'NAMELSAD',
#        'ALAND', 'AWATER', 'INTPTLAT', 'INTPTLON'],
#       dtype='object')

# %%
new_df = new_df[["NAMELSAD", "FLD_ZONE", "ZONE_SUBTY", "SFHA_TF", "GEOID"]]
new_df.head()
# Out:
#             NAMELSAD FLD_ZONE                    ZONE_SUBTY SFHA_TF  \
# 0  Census Tract 9601        X  AREA OF MINIMAL FLOOD HAZARD       F
# 1  Census Tract 9601       AE                           NaN       T
# 2  Census Tract 9601       AE                           NaN       T
# 3  Census Tract 9601        A                           NaN       T
# 4  Census Tract 9601       AE                      FLOODWAY       T
#
#           GEOID
# 0  2.200196e+10
# 1  2.200196e+10
# 2  2.200196e+10
# 3  2.200196e+10
# 4  2.200196e+10

# %%
new_df.shape
# Out:
# (147520, 5)

# %%
new_df["Tract"]= new_df["NAMELSAD"].str[13:]
new_df = new_df.drop(columns =["NAMELSAD"])

# %%
new_df.head()
# Out:
#   FLD_ZONE                    ZONE_SUBTY SFHA_TF         GEOID Tract
# 0        X  AREA OF MINIMAL FLOOD HAZARD       F  2.200196e+10  9601
# 1       AE                           NaN       T  2.200196e+10  9601
# 2       AE                           NaN       T  2.200196e+10  9601
# 3        A                           NaN       T  2.200196e+10  9601
# 4       AE                      FLOODWAY       T  2.200196e+10  9601

# %%
new_df.shape
# Out:
# (147520, 5)

# %%
df_clean = new_df.drop_duplicates()

# %%
df_clean.shape
# Out:
# (2759, 5)

# %%
df_clean.head()
# Out:
#   FLD_ZONE                          ZONE_SUBTY SFHA_TF         GEOID Tract
# 0        X        AREA OF MINIMAL FLOOD HAZARD       F  2.200196e+10  9601
# 1       AE                                 NaN       T  2.200196e+10  9601
# 3        A                                 NaN       T  2.200196e+10  9601
# 4       AE                            FLOODWAY       T  2.200196e+10  9601
# 6        X  0.2 PCT ANNUAL CHANCE FLOOD HAZARD       F  2.200196e+10  9601

# %%
df_clean = df_clean.reset_index(drop=True)

# %%
df_clean.head()
# Out:
#   FLD_ZONE                          ZONE_SUBTY SFHA_TF Tract
# 0        X        AREA OF MINIMAL FLOOD HAZARD       F  9601
# 1       AE                                 NaN       T  9601
# 2        A                                 NaN       T  9601
# 3       AE                            FLOODWAY       T  9601
# 4        X  0.2 PCT ANNUAL CHANCE FLOOD HAZARD       F  9601

# %%
df_clean.shape
df_clean.dtypes
# Out:
# FLD_ZONE      object
# ZONE_SUBTY    object
# SFHA_TF       object
# Tract         object
# dtype: object

# %%
df_clean
# Out:
#      FLD_ZONE                                 ZONE_SUBTY SFHA_TF    Tract
# 0           X               AREA OF MINIMAL FLOOD HAZARD       F     9601
# 1          AE                                        NaN       T     9601
# 2           A                                        NaN       T     9601
# 3          AE                                   FLOODWAY       T     9601
# 4           X         0.2 PCT ANNUAL CHANCE FLOOD HAZARD       F     9601
# 5           A                                        NaN       T     9602
# 6           X               AREA OF MINIMAL FLOOD HAZARD       F     9602
# 7          AE                                        NaN       T     9602
# 8           X         0.2 PCT ANNUAL CHANCE FLOOD HAZARD       F     9602
# 9          AE                                   FLOODWAY       T     9602
# 10         AE                                        NaN       T     9603
# 11         AE                                   FLOODWAY       T     9603
# 12          A                                        NaN       T     9603
# 13          X               AREA OF MINIMAL FLOOD HAZARD       F     9603
# 14          X         0.2 PCT ANNUAL CHANCE FLOOD HAZARD       F     9603
# 15          A                                        NaN       T     9604
# 16          X               AREA OF MINIMAL FLOOD HAZARD       F     9604
# 17          X         0.2 PCT ANNUAL CHANCE FLOOD HAZARD       F     9604
# 18         AE                                        NaN       T     9604
# 19         AE                                   FLOODWAY       T     9604
# 20          X         0.2 PCT ANNUAL CHANCE FLOOD HAZARD       F     9605
# 21          A                                        NaN       T     9605
# 22          X               AREA OF MINIMAL FLOOD HAZARD       F     9605
# 23         AE                                        NaN       T     9606
# 24         AE                                   FLOODWAY       T     9606
# 25          X               AREA OF MINIMAL FLOOD HAZARD       F     9606
# 26          A                                        NaN       T     9606
# 27          X         0.2 PCT ANNUAL CHANCE FLOOD HAZARD       F     9606
# 28          X               AREA OF MINIMAL FLOOD HAZARD       F     9607
# 29         AH                                        NaN       T     9607
# ...       ...                                        ...     ...      ...
# 2119       AE                                        NaN       T  9501.01
# 2120       AE                                   FLOODWAY       T  9501.01
# 2121        A                                        NaN       T  9501.02
# 2122        X         0.2 PCT ANNUAL CHANCE FLOOD HAZARD       F  9501.02
# 2123        X               AREA OF MINIMAL FLOOD HAZARD       F  9501.02
# 2124       AE                                        NaN       T  9501.02
# 2125        X               AREA OF MINIMAL FLOOD HAZARD       F     9510
# 2126        A                                        NaN       T     9510
# 2127       AE                                        NaN       T     9509
# 2128        A                                        NaN       T      311
# 2129        X               AREA OF MINIMAL FLOOD HAZARD       F      312
# 2130        X               AREA OF MINIMAL FLOOD HAZARD       F      314
# 2131        A                                        NaN       T      314
# 2132        A                                        NaN       T      315
# 2133        X               AREA OF MINIMAL FLOOD HAZARD       F      315
# 2134       AE                                        NaN       T      317
# 2135        A                                        NaN       T      317
# 2136        X               AREA OF MINIMAL FLOOD HAZARD       F      320
# 2137        X               AREA OF MINIMAL FLOOD HAZARD       F      321
# 2138        A                                        NaN       T      321
# 2139        X  AREA WITH REDUCED FLOOD RISK DUE TO LEVEE       F   204.02
# 2140        X               1 PCT DEPTH LESS THAN 1 FOOT       F        1
# 2141        X               1 PCT DEPTH LESS THAN 1 FOOT       F        2
# 2142        X               1 PCT DEPTH LESS THAN 1 FOOT       F        3
# 2143        X               AREA OF MINIMAL FLOOD HAZARD       F     9518
# 2144        A                                        NaN       T      318
# 2145        X  AREA WITH REDUCED FLOOD RISK DUE TO LEVEE       F      203
# 2146        X               AREA OF MINIMAL FLOOD HAZARD       F  9517.01
# 2147        X               AREA OF MINIMAL FLOOD HAZARD       F      NaN
# 2148       AE                                        NaN       T      NaN
#
# [2149 rows x 4 columns]

# %%
# df_clean.to_csv(os.path.join(local_folder, 'nfhl_tiger.csv', dtype={'Tract': object}), index = False, header=True)
df_clean.to_pickle("./nfhl_tiger.pkl")

# %%
df_clean.head()

# %%
df_clean.dtypes
